# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Output/HO_Gauss_RU.txt", delim_whitespace = True, skiprows = 8, skipfooter = 1, engine="python")

alpha = df["Param_1"]
E = df["E"]

display(df)
# Out:
#     Param_1         E       E^2       VAR
# 0      0.40  0.513403  0.290075  0.026492
# 1      0.41  0.510277  0.281172  0.020789
# 2      0.42  0.506548  0.271326  0.014736
# 3      0.43  0.505629  0.267214  0.011554
# 4      0.44  0.504010  0.262083  0.008057
# 5      0.45  0.502835  0.258379  0.005536
# 6      0.46  0.501297  0.254712  0.003414
# 7      0.47  0.501263  0.253173  0.001908
# 8      0.48  0.500415  0.251239  0.000824
# 9      0.49  0.500009  0.250210  0.000201
# 10     0.50  0.500000  0.250000  0.000000
# 11     0.51  0.500094  0.250294  0.000201
# 12     0.52  0.500256  0.251036  0.000780
# 13     0.53  0.500887  0.252575  0.001687
# 14     0.54  0.502029  0.254920  0.002887
# 15     0.55  0.502350  0.256971  0.004616
# 16     0.56  0.503200  0.259648  0.006438
# 17     0.57  0.504641  0.263184  0.008521
# 18     0.58  0.506217  0.267045  0.010789
# 19     0.59  0.506917  0.270695  0.013731
# 20     0.60  0.510611  0.276383  0.015659

# %%
plt.plot(alpha, E)
plt.show()
