# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Output/HO_Gauss_RU.txt", delim_whitespace = True, skiprows = 8, skipfooter = 1, engine="python")

alpha = df["Param_1"]
E = df["E"]

# %%
plt.plot(alpha, E)
plt.show()

# %%
display(df)
# Out:
#     Param_1         E       E^2           VAR
# 0      0.40  0.513107  0.289386  2.610730e-02
# 1      0.41  0.509636  0.279240  1.951170e-02
# 2      0.42  0.508265  0.273907  1.557320e-02
# 3      0.43  0.506425  0.267975  1.150940e-02
# 4      0.44  0.502057  0.259716  7.655200e-03
# 5      0.45  0.503231  0.259105  5.863940e-03
# 6      0.46  0.501260  0.254646  3.384220e-03
# 7      0.47  0.501270  0.253278  2.006560e-03
# 8      0.48  0.500135  0.250949  8.132880e-04
# 9      0.49  0.500128  0.250335  2.072070e-04
# 10     0.50  0.500000  0.250000  2.775560e-17
# 11     0.51  0.500196  0.250389  1.928320e-04
# 12     0.52  0.500218  0.250989  7.711570e-04
# 13     0.53  0.500822  0.252511  1.688870e-03
# 14     0.54  0.502213  0.255093  2.875050e-03
# 15     0.55  0.501996  0.256571  4.570240e-03
# 16     0.56  0.502280  0.258932  6.646300e-03
# 17     0.57  0.504145  0.262828  8.665770e-03
# 18     0.58  0.504734  0.266141  1.138440e-02
# 19     0.59  0.507749  0.271363  1.355350e-02
# 20     0.60  0.509303  0.275906  1.651730e-02
